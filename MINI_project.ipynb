# %% [markdown]
# # **MINI PROJECT DEVL**

# %% [markdown]
# ## **Exploratory Data Analysis (EDA) with Pandas in Banking**

# %% [markdown]
# **Department of Computer Engineering (RL)**
# **Course:** Data Exploration and visualization
#
#
#   **Title:**
#  EDA on Bank Marketing Dataset using Pandas and Seaborn
#
# **Submitted by:**
# Name: Sanskruti A. Soitkar PRN:124B1D036
# Name: Ayush S. Patil       PRN:124B1D044
#
# **Guided by:** Prof. Ganesh Deshmukh
#
# **Academic Year:** 2025–26

# %% [markdown]
# ## **OBJECTIVE:**
# The purpose of this project is to master the exploratory data analysis (EDA) in banking with Pandas framework.
#
# Goals of the Project:
#
#
#
# Explore and analyze a banking dataset using the Pandas framework.
#
# *   Explore and analyze a banking dataset using the Pandas framework.
# *   Visualize key patterns and relationships using various plot types.
# *   Interpret the data to understand marketing effectiveness.

# %% [markdown]
# ##**1. Importing Required Libraries**

# %% [markdown]
# Importing the libraries necessary for this project. We can add some aliases to make the libraries easier to use in our code and set a default figure size for further plots.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns


# %matplotlib inline
plt.rcParams["figure.figsize"] = (8, 6)

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Further specify the value of the precision parameter equal to 2 to display two decimal signs (instead of 6 as default).

# %%
pd.options.display.float_format = '{:.2f}'.format

# %% [markdown]
# ## **2. Dataset exploration**
# In this section we will explore the sourse dataset.
#
# Let's read the data and look at the first 5 rows using the head method. The number of the output rows from the dataset is determined by the head method parameter.

# %%
df = pd.read_csv('/content/bank-dataset-use-for-marketing.csv', sep = ';')
df.head(5)
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent         1.10
# 1   may         mon  ...         1    999         0  nonexistent         1.10
# 2   may         mon  ...         1    999         0  nonexistent         1.10
# 3   may         mon  ...         1    999         0  nonexistent         1.10
# 4   may         mon  ...         1    999         0  nonexistent         1.10
#
# ...

# %% [markdown]
# Let's look at the dataset size, feature names and their types

# %%
df.shape
df.tail(5)
# Out:
#        age          job  marital            education default housing loan  \
# 41183   73      retired  married  professional.course      no     yes   no
# 41184   46  blue-collar  married  professional.course      no      no   no
# 41185   56      retired  married    university.degree      no     yes   no
# 41186   44   technician  married  professional.course      no      no   no
# 41187   74      retired  married  professional.course      no     yes   no
#
#         contact month day_of_week  ...  campaign  pdays  previous  \
# 41183  cellular   nov         fri  ...         1    999         0
# 41184  cellular   nov         fri  ...         1    999         0
# 41185  cellular   nov         fri  ...         2    999         0
# 41186  cellular   nov         fri  ...         1    999         0
# 41187  cellular   nov         fri  ...         3    999         1
#
#           poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# ...

# %% [markdown]
# The dataset contains 41188 objects (rows), for each of which 21 features are set (columns), including 1 target feature (y).
#
# ## **3. Attributing information**
# Output the column (feature) names:

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %% [markdown]
# To see the general information on all the DataFrame features (columns), we use the info method:

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
# ...

# %% [markdown]
# As we can see, the dataset is full, no pass (non-null), so there is no need to fill the gaps. The dataset contains 5 integer (int64), 5 real (float64) and 11 categorical and binary (object) features.
#
# Method describe shows the main statistical characteristics of the dataset for each numerical feature (int64 and float64 types): the existing values number, mean, standard deviation, range, min & max, 0.25, 0.5 and 0.75 quartiles.

# %% [markdown]
# ## **4. Descriptive Statistics**

# %%
df.describe()
# Out:
#            age  duration  campaign    pdays  previous  emp.var.rate  \
# count 41188.00  41188.00  41188.00 41188.00  41188.00      41188.00
# mean     40.02    258.29      2.57   962.48      0.17          0.08
# std      10.42    259.28      2.77   186.91      0.49          1.57
# min      17.00      0.00      1.00     0.00      0.00         -3.40
# 25%      32.00    102.00      1.00   999.00      0.00         -1.80
# 50%      38.00    180.00      2.00   999.00      0.00          1.10
# 75%      47.00    319.00      3.00   999.00      0.00          1.40
# max      98.00   4918.00     56.00   999.00      7.00          1.40
#
#        cons.price.idx  cons.conf.idx  euribor3m  nr.employed
# count        41188.00       41188.00   41188.00     41188.00
# mean            93.58         -40.50       3.62      5167.04
# std              0.58           4.63       1.73        72.25
# min             92.20         -50.80       0.63      4963.60
# ...

# %% [markdown]
# To see the statistics on non-numeric features, we need to explicitly specify the feature types by the include parameter. We can also set include = all to output statistics on all the existing features.

# %%
df.describe(include = ["object"])
# Out:
#            job  marital          education default housing   loan   contact  \
# count    41188    41188              41188   41188   41188  41188     41188
# unique      12        4                  8       3       3      3         2
# top     admin.  married  university.degree      no     yes     no  cellular
# freq     10422    24928              12168   32588   21576  33950     26144
#
#         month day_of_week     poutcome      y
# count   41188       41188        41188  41188
# unique     10           5            3      2
# top       may         thu  nonexistent     no
# freq    13769        8623        35563  36548

# %% [markdown]
# The result shows that the average client refers to administrative staff (job = admin.), is married (marital = married) and has a university degree (education = university.degree).
#
# For categorical (type object) and boolean (type bool) features you can use the value_counts method. Let's look at the target feature (y) distribution:

# %% [markdown]
# ## **5. Checking Target Variable Distribution**

# %%
df["y"].value_counts()
# Out:
# y
# no     36548
# yes     4640
# Name: count, dtype: int64

# %% [markdown]
# Let's look at the client distribution by the variable marital. Specify the value of the normalize = True parameter to view relative frequencies, but not absolute.

# %% [markdown]
# ## **6. Checking Martial Distribution**

# %%
df["marital"].value_counts(normalize = True)
# Out:
# marital
# married    0.61
# single     0.28
# divorced   0.11
# unknown    0.00
# Name: proportion, dtype: float64

# %% [markdown]
# As we can see, 61% (0.61) of clients are married, which must be taken into account when planning marketing campaigns to manage deposit operations.
#
# # **7. Data Sorting and filtering**
# A DataFrame can be sorted by a few feature values. In our case, for example, by duration (ascending = False for sorting in descending order):

# %%
df.sort_values(by = "duration", ascending = False).head()
# Out:
#        age          job  marital            education default housing loan  \
# 24091   33   technician   single  professional.course      no     yes   no
# 22192   52  blue-collar  married             basic.4y      no      no   no
# 40537   27       admin.   single          high.school      no      no   no
# 13820   31   technician  married  professional.course      no      no   no
# 7727    37   unemployed  married  professional.course      no     yes   no
#
#          contact month day_of_week  ...  campaign  pdays  previous  \
# 24091  telephone   nov         mon  ...         1    999         0
# 22192  telephone   aug         thu  ...         3    999         0
# 40537  telephone   aug         fri  ...         1    999         0
# 13820   cellular   jul         thu  ...         1    999         0
# 7727   telephone   may         fri  ...         2    999         0
#
#           poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# ...

# %% [markdown]
# The sorting results show that the longest calls exceed one hour, as the value duration is more than 3600 seconds or 1 hour. At the same time, it usually was on Mondays and Thursdays (day_of_week) and, especially, in November and August (month).
#
# Sort by the column group:

# %%
df.sort_values(by = ["age", "duration"], ascending = [True, False]).head()
# Out:
#        age      job marital education default  housing     loan   contact  \
# 38274   17  student  single   unknown      no       no      yes  cellular
# 37579   17  student  single  basic.9y      no  unknown  unknown  cellular
# 37140   17  student  single   unknown      no      yes       no  cellular
# 37539   17  student  single  basic.9y      no      yes       no  cellular
# 37558   17  student  single  basic.9y      no      yes       no  cellular
#
#       month day_of_week  ...  campaign  pdays  previous  poutcome  \
# 38274   oct         tue  ...         1      2         2   success
# 37579   aug         fri  ...         2    999         1   failure
# 37140   aug         wed  ...         3      4         2   success
# 37539   aug         fri  ...         2    999         2   failure
# 37558   aug         fri  ...         3      4         2   success
#
#       emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed    y
# ...

# %% [markdown]
# We see that the youngest customers are at the age of 17, and the call duration exceeded 3 minutes only for three clients, which indicates the ineffectiveness of long-term interaction with such clients.

# %% [markdown]
# To ensure data quality, it’s important to check whether the dataset contains any duplicate rows.
# We can do this using the duplicated() method combined with sum(), which counts how many rows are repeated in the dataset.
# ## **8. Checking for duplicate**

# %%
df.duplicated().sum()
# Out:
# np.int64(12)

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# There are 12 duplicate rows in the dataset.
# These duplicate entries should be removed to ensure the dataset remains clean and the analysis results are accurate.

# %% [markdown]
# We see that the youngest customers are at the age of 17, and the call duration exceeded 3 minutes only for three clients, which indicates the ineffectiveness of long-term interaction with such clients.
#
# ### **9. Applying functions and maping**
# Apply the function to each column:

# %%
df.select_dtypes(include=np.number).apply(np.max)
# Out:
# age                98.00
# duration         4918.00
# campaign           56.00
# pdays             999.00
# previous            7.00
# emp.var.rate        1.40
# cons.price.idx     94.77
# cons.conf.idx     -26.90
# euribor3m           5.04
# nr.employed      5228.10
# dtype: float64

# %% [markdown]
# The map can also be used for the values ​​replacement in a column by passing it as an argument dictionary in form of {old_value: new_value} .

# %%
d = {"no": 0, "yes": 1}
df["y"] = df["y"].map(d)
df.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent         1.10
# 1   may         mon  ...         1    999         0  nonexistent         1.10
# 2   may         mon  ...         1    999         0  nonexistent         1.10
# 3   may         mon  ...         1    999         0  nonexistent         1.10
# 4   may         mon  ...         1    999         0  nonexistent         1.10
#
# ...

# %% [markdown]
# ### **10. Indexing and extracting data**
#
# A DataFrame can be indexed in many ways. In this regard, consider various ways of indexing and extracting data from the DataFrame with simple question examples.
#
# We can use the code dataframe ['name'] to extract a separate column. We use this to answer the question:
# ### **What is the share of clients attracted in our DataFrame?**

# %%
print("Share of attracted clients =", '{:.1%}'.format(df["y"].mean()))
# Out:
# Share of attracted clients = 11.3%

# %% [markdown]
# Share of attracted clients = 11.3%
# 11,3% is a rather bad indicator for a bank, with such a percentage of attracted customers a business can collapse.
#
# Logical indexation by one column of a DataFrame is very convenient. It looks like this: df [p(df['Name']], where p is a certain logical condition that is checked for each element of the Name column. The result of such an indexation is a DataFrame consisting only of the rows satisfying the condition p by the Name column.
#
# We use this to answer the question:
# ### **What are the mean values ​​of numerical features among the attracted clients?**

# %%
df_attracted = df[df["y"] == 1]
print("Mean of numerical features for attracted clients:")
print(df_attracted.select_dtypes(include=np.number).mean())
# Out:
# Mean of numerical features for attracted clients:
# age                40.91
# duration          553.26
# campaign            2.05
# pdays             791.99
# previous            0.49
# emp.var.rate       -1.23
# cons.price.idx     93.35
# cons.conf.idx     -39.79
# euribor3m           2.12
# nr.employed      5095.12
# y                   1.00
# dtype: float64

# %% [markdown]
# Thus, the average age of the attracted clients is about 40 (age = 40.91), and 2 calls were required to attract them (campaign = 2.05).
#
# Combining two previous types of indexation, we will answer the question:
# ### **What is the average call duration for the attracted clients?**

# %%
acd = round(df[df["y"] == 1]["duration"].mean(), 2)
acd_in_min = acd // 60
print("Average call duration for attracted clients =", acd_in_min, "min", int(acd) % 60, "sec")
# Out:
# Average call duration for attracted clients = 9.0 min 13 sec

# %% [markdown]
# Average call duration for attracted clients = 9.0 min 13 sec
# So, the average duration of a successful call is almost 553 seconds, that is, nearly 10 minutes.
#
# ### **What is the average age of attracted (y == 1) and unmarried ('marital' == 'single') clients?**

# %%
print("Average age of attracted clients =", int(df[(df["y"] == 1) & (df["marital"] == "single")]["age"].mean()), "years")
# Out:
# Average age of attracted clients = 31 years

# %% [markdown]
# The average age of unmarried attracted clients is 31, which should be considered when working with such clients.
#
# If we need to get the first or last line of the DataFrame, we can use the code df[:1] or df[-1:]:

# %%
df[-1:]
# Out:
#        age      job  marital            education default housing loan  \
# 41187   74  retired  married  professional.course      no     yes   no
#
#         contact month day_of_week  ...  campaign  pdays  previous  poutcome  \
# 41187  cellular   nov         fri  ...         3    999         1   failure
#
#       emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed  y
# 41187        -1.10           94.77         -50.80       1.03      4963.60  0
#
# [1 rows x 21 columns]

# %% [markdown]
# # **11. Visualization in Pandas**
#
# Method scatter_matrix allows you to visualize the pairwise dependencies between the features (as well as the distribution of each feature on the diagonal). We will do it for numerical features.

# %%
pd.plotting.scatter_matrix(
    df[["age", "duration", "campaign"]],
    figsize = (15, 15),
    diagonal = "kde")
plt.show()

# %% [markdown]
# A scatter matrix (pairs plot) compactly plots all the numeric variables we have in a dataset against each other. The plots on the main diagonal allow you to visually define the type of data distribution: the distribution is similar to normal for age, and for a call duration and the number of contacts, the geometric distribution is more suitable.
#
# ### **12.Now We will build a separate histogram for age feature:**

# %%
df["age"].hist()
# Out:
# <Axes: >

# %% [markdown]
# The histogram shows that most of our clients are between the ages of 25 and 50, which corresponds to the actively working part of the population.
#
# ### **13. Now we will build histogram for features all together:**

# %%
df.hist(color = "k",
        bins = 30,
        figsize = (15, 10))
plt.show()

# %% [markdown]
# A visual analysis of the histograms presented allows us to make preliminary assumptions about the variability of the source data.
#
# Now we will use Box Plot.
#
# It will allow us to compactly visualize the main characteristics of the feature distribution (the median, lower and upper quartile, minimal and maximum, outliers).

# %% [markdown]
# The plot shows that unmarried people are on average younger than divorced and married ones. For the last two groups, there is an outlier zone over 70 years old, and for unmarried - over 50.
#
# ### **14.Now we will try to do this by data grouping on other features:**

# %%
df.boxplot(column = "age",
           by = ["marital", "housing"],
           figsize = (20, 20))
plt.show()

# %% [markdown]
# After comparing age across marital groups, we can also examine how age varies with customers’ education levels.
# This helps identify whether certain education categories are associated with specific age groups, which may influence marketing strategies.
#
# ## **15.Age Distribution by Education Level**

# %%
df.boxplot(column = "age",
  by = "education",
  figsize = (15, 15))
plt.show()

# %% [markdown]
# From the plot, we can see that customers with primary education tend to be older, while those with university degrees are generally younger and fall within a tighter age range.
# This indicates that educational background may also relate to age distribution in the customer base.

# %% [markdown]
# ##**16.Visualizing Target Variable**
#
# We first examine the target variable 'y', which represents whether a customer
# subscribed ('yes') or did not subscribe ('no') to the term deposit. This will
# help us understand the class distribution and whether the data is imbalanced.
# """

# %%
sns.countplot(x='y', data=df)
plt.title("Term Deposit Subscription Distribution")
plt.show()

# %% [markdown]
# From the chart, we see that most customers did not subscribe ('no') to the term deposit.
# Only a smaller portion responded positively ('yes'). This shows class imbalance,
# indicating the marketing campaign had limited success.
#
# # **17.Visualizing Age**
# Customer age is a key demographic feature. Understanding its distribution helps
# us identify the major customer segments and target age groups for marketing.

# %%
sns.histplot(df['age'], bins=20, kde=True)
plt.title("Age Distribution of Customers")
plt.xlabel("Age")
plt.show()

# %% [markdown]
# Most customers are between 30 and 50 years old. Younger (below 25) and older (above 60)
# age groups are fewer. Hence, the campaign mainly targeted working-age adults.
#
# #**18.Visualizing Job Types**
#
# The job type of customers provides insight into the bank’s target audience.
# We’ll plot the frequency of each job category to see which occupations are
# most represented in the dataset.

# %%
plt.figure(figsize=(12,6))
sns.countplot(y='job', data=df, order=df['job'].value_counts().index)
plt.title("Customer Count by Job Type")
plt.show()

# %% [markdown]
# The most common job types are 'blue-collar', 'management', and 'technician'.
# Smaller groups include 'student' and 'unemployed', showing the bank's primary
# focus on working professionals.
#
# # **19.Marital Status Impact**
# Marital status can influence financial decisions. Here, we analyze how
# the marital status (single, married, divorced) affects the likelihood
# of subscribing to a term deposit.

# %%
sns.countplot(x='marital', data=df,palette='pastel')
plt.xticks(rotation=45)
plt.title("Distribution by Marital Status")
plt.show()

# %% [markdown]
# Married customers form the largest group, but single customers have a relatively
# higher proportion of 'yes' responses. This shows marital status slightly affects
# the subscription outcome.
#
# # **20.Education Impact**
#
# Education level reflects awareness and financial literacy. Here, we examine
# whether more educated customers show a higher tendency to subscribe to
# the bank's term deposit.

# %%
sns.countplot(x='education', data=df)
plt.xticks(rotation=45)
plt.title("Distribution by Education Level")
plt.show()

# %% [markdown]
# # **21.Adjusting Display Precision for Numerical Values**
#
# By default, pandas displays floating-point numbers with many decimal places,
# which can make tables look cluttered.
#
# The command below sets the number of decimal places displayed to 2,
# making the output cleaner and easier to read.

# %%
pd.set_option('display.precision', 2)

# %% [markdown]
# # **22.Mean of Numerical Features**
#
# To understand the central tendency of our dataset, we calculate the mean (average) value for all numerical columns.
# This helps identify the overall trends and typical values across different numerical attributes.

# %%
numeric_means = df.select_dtypes(include=['number']).mean()
print(numeric_means)
# Out:
# age                40.02
# duration          258.32
# campaign            2.57
# pdays             962.46
# previous            0.17
# emp.var.rate        0.08
# cons.price.idx     93.58
# cons.conf.idx     -40.50
# euribor3m           3.62
# nr.employed      5167.03
# y                   0.11
# dtype: float64

# %% [markdown]
# ##**23.Correlation Heatmap of Numeric Features**
# This heatmap helps visualize how numerical features are related.
# It shows whether features like age, balance, and duration have
# strong positive or negative correlations with each other.

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.select_dtypes(include=np.number).corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap of Numerical Features")
plt.show()6

# %% [markdown]
# # **24.Job Type Impact**
#
# The customer’s occupation can influence their financial behavior and likelihood of subscribing to a term deposit.
# We visualize how subscription rates vary across different job categories to identify which groups are more responsive to marketing efforts.

# %%
plt.figure(figsize=(12,6))
sns.countplot(y='job', hue='y', data=df)
plt.title("Deposit Subscription by Job Type")
plt.show()

# %% [markdown]
# The plot shows that customers working in management, technician, and blue-collar jobs form the largest groups.
# However, students and retired customers have a higher proportion of ‘yes’ responses, suggesting these groups are more likely to subscribe to term deposits.
# # **25.Marital Status Impact**
#
# Marital status can affect a customer's financial goals and investment behavior.
# Here, we analyze how the likelihood of subscribing to a term deposit varies across single, married, and divorced customers.

# %%
sns.countplot(x='marital', hue='y', data=df)
plt.title("Subscription Status by Marital Status")
plt.show()

# %% [markdown]
# The plot shows that married customers form the largest group, but single customers have a relatively higher proportion of ‘yes’ responses.
# This suggests that marital status slightly influences the subscription outcome.
#
# # **26.Education Impact**
#
# Education often reflects a person’s financial awareness and decision-making ability.
# We examine how customers with different education levels respond to the bank’s term deposit offers.

# %%
sns.countplot(x='education', hue='y', data=df)
plt.xticks(rotation=45)
plt.title("Subscription Status by Education Level")
plt.show()

# %% [markdown]
# From the chart, we observe that customers with university degrees are somewhat more likely to subscribe compared to those with only secondary or primary education.
# This indicates that higher education levels may correlate with greater interest in investment opportunities.
#
# # **27.Call Duration Analysis**
# Duration of the last marketing call is a critical feature — longer conversations
# may indicate better engagement and persuasion. We use a boxplot to compare
# call durations between subscribers and non-subscribers.

# %%
sns.boxplot(x='y', y='duration', data=df)
plt.title("Duration of Last Contact vs Subscription")
plt.show()

# %% [markdown]
# ##**Key Insights from EDA**
# - Customers with **higher balances and longer call durations** are more likely to subscribe to term deposits.
# - **Married customers** and those with **secondary or tertiary education** show higher subscription rates.
# - **Job type** also plays a major role — administrative and management roles respond better to campaigns.
# - Duration of contact call is the most significant factor influencing subscription.
#
#
# ##**Conclusion**
# This mini-project successfully demonstrates how Exploratory Data Analysis can uncover hidden trends in marketing data.
# The findings help banks design more targeted marketing strategies, improving campaign success rates.
